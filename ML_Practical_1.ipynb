# %% [markdown]
# <a href="https://colab.research.google.com/github/Kul200528/ML/blob/main/ML_Practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Machine Learning!")
# Out:
# Hello Machine Learning!
